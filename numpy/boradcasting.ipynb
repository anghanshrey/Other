# %%
import numpy as np

# %% [markdown]
# ##### Basic Filtering

# %%
ages = np.array([25, 30, 18, 44, 21, 17, 21])

adults = ages[ages >= 18]

print(adults)
# Out:
# [25 30 18 44 21 21]

# %%
adults_age = ages[(ages > 20) & (ages < 35)]

print(adults_age)
# Out:
# [25 30 21 21]

# %%
names = np.array(["Rahul" , "Alice", "Bob", "Carlice" , "Akash"])

selected_names = names[np.char.startswith(names, "A") | np.char.startswith(names, "R")]

print(selected_names)
# Out:
# ['Rahul' 'Alice' 'Akash']

# %% [markdown]
# #### Basic Masking Selection

# %%
temp = np.array([28, 32 , 35, 30, 22])

is_hot = temp > 30

hot_temp = temp[is_hot]

print(temp)
print(is_hot)
print(hot_temp)
# Out:
# [28 32 35 30 22]
# [False  True  True False False]
# [32 35]

# %% [markdown]
# #### Masing for Modification

# %%
temp[is_hot] = 31

print(temp)
# Out:
# [28 31 31 30 22]

# %% [markdown]
# ##### np.where

# %%
scores = np.where([68 , 81 , 78 , 90 , 55 , 78])

# if score >= 75 -> pass otherwise fail

grades = np.where(scores >= 75 , "pass" , "Fail")

print(scores)

print(grades)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 5
#       1 scores = np.where([68 , 81 , 78 , 90 , 55 , 78])
#       2
#       3 # if score >= 75 -> pass otherwise fail
#       4
# ----> 5 grades = np.where(scores >= 75 , "pass" , "Fail")
#       6
#       7 print(scores)
#       8
#
# TypeError: '>=' not supported between instances of 'tuple' and 'int'
