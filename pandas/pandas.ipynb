# %%
import pandas as pd

# %% [markdown]
# #### Series

# %%
lists = pd.Series(["Rahul", "Rohit", "Robinson", "Robin"])

print(lists)
# Out:
# 0       Rahul
# 1       Rohit
# 2    Robinson
# 3       Robin
# dtype: str

# %%
multiple = pd.Series(["Rahul", 18, 2006])

print(multiple)
# Out:
# 0    Rahul
# 1       18
# 2     2006
# dtype: object

# %% [markdown]
# #### DataFrame

# %%
student = pd.DataFrame([["Rahul", 18], ["Rohit", 20], ["Shrey", 22], ["Mohit", 24]], columns=["Name", "Age"])

print(student)
# Out:
#     Name  Age
# 0  Rahul   18
# 1  Rohit   20
# 2  Shrey   22
# 3  Mohit   24
